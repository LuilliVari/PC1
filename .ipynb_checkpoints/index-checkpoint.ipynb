# %% [markdown]
# ## Read the data
#
# This code will give you the data you will use for this PC:

# %%
# read web table into pandas DF
import pandas as pd

co2Link='https://docs.google.com/spreadsheets/d/e/2PACX-1vRXjfxeKHQBBCh_oHP-D6RIHEX4eduLjydHb6ZGsU4jo0IK0KKQSoYX_X1FGssC_9hnqCgjKN0K4AVf/pub?gid=775098192&single=true&output=csv'
carbon=pd.read_csv(co2Link)

# %%
# here it is:
carbon
# Out:
#                                               name  metric tonnes of CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information  ranking                             region
# ...

# %% [markdown]
# As you see, some columns have space, which should be deleted:

# %%
# also
carbon.columns
# Out:
# Index(['name', 'metric tonnes of CO2', 'date_of_information', 'ranking',
#        'region'],
#       dtype='object')

# %%
# Like this
carbon.rename(columns={'metric tonnes of CO2':'metric_tonnes_of_CO2'},inplace=True)

# see
carbon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  216 non-null    object
#  1   metric_tonnes_of_CO2  216 non-null    float64
#  2   date_of_information   216 non-null    int64
#  3   ranking               216 non-null    int64
#  4   region                216 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 8.6+ KB

# %% [markdown]
# You always make a copy:

# %%
carbon_copy=carbon.copy()

# %% [markdown]
# ## Questions

# %% [markdown]
# Complete the tasks requested using **carbon_copy**:
#
# 1. Keep all the columns but _Ranking_:
#     * Tip: use [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html), [loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html), and [iloc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html) for the same purpose (three ways to accomplish the task).
#
# 2. Find the country with the minimum CO2 emission in the world.
#
# 3. Find the country with the minimum CO2 emission per Region.
#
# 4. Create a new column by keeping the square root of the the original CO2  column.
#
# 5. Compute the average of CO2. Then, create a new column. This new column is
# the original CO2 minus the average computed.
#
# You have changed **carbon_copy**, now save it as a file like this:

# %% [markdown]
# ###Parte I

# %% [markdown]
# Nos piden eliminar la columna de ***ranking*** en la tabla para eso se establecio una copia ***carbon_copy***

# %%
#Usamos la entrada 'bye_Columns' para establecer lo que queremos eliminar.
bye_Columns=['ranking']

#Primero usamos la funcion '.drop()', la cula nos da acceso a objetos de tipo DataFrame.
carbon_copy.drop(columns=bye_columns,inplace=True)

#Devolvemos la tabla con el cambio realizado.
carbon_copy
# Out:
#                                               name  metric_tonnes_of_CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information                             region
# ...

# %%
#LLamamos de nuevo a la copia para hacer el mimso procedimiento.
carbon_copy=carbon.copy()

#Pero en esta ocasion usaremos la funcion .loc[] para seleccionar la columna que quiero omitir en la tabla.
carbon_copy=carbon_copy.loc[:, carbon_copy.columns !='ranking']

#Devolvemos la tabla con el cambio realizado.
carbon_copy
# Out:
#                                               name  metric_tonnes_of_CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information                             region
# ...

# %%
#Realizamos el mismo procedimiento con la funcion .iloc[].
#La unica diferencia es que usamos indices enteros para elegir las columnas a conservar.
#O tambien se pudo haber usado 'carbon_copy.columns != "ranking"'
carbon_copy=carbon.copy()
carbon_copy=carbon_copy.iloc[:, [0,1,2,4]]
carbon_copy
# Out:
#                                               name  metric_tonnes_of_CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information                             region
# ...

# %%
#Determinamos el pais con la menor emision del mundo
#Continuamos trabajando con la copia realizada
carbon_copy[carbon_copy.metric_tonnes_of_CO2==carbon_copy.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 215    Niue
# Name: name, dtype: object

# %% [markdown]
# ###Parte II

# %% [markdown]
# Determinamos el pais con menor emision de CO2 por cada region.
# Para este caso tenemos ****['Europe' , 'East and Southeast Asia' , 'North America' , 'South Asia' , 'Central Asia' , 'Central America and the Caribbean' , 'South America','Africa' ,'Antarctica' , 'Australia and Oceania' , 'Middle East']***

# %%
#1
femdf=carbon_copy[carbon_copy["region"]=='Europe']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 175    Faroe Islands
# Name: name, dtype: object

# %%
#2
femdf=carbon_copy[carbon_copy["region"]=='East and Southeast Asia']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 184    Timor-Leste
# Name: name, dtype: object

# %%
#3
femdf=carbon_copy[carbon_copy["region"]=='North America']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 210    Saint Pierre and Miquelon
# Name: name, dtype: object

# %%
#4
femdf=carbon_copy[carbon_copy["region"]=='South Asia']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 177    Bhutan
# Name: name, dtype: object

# %%
#5
femdf=carbon_copy[carbon_copy["region"]=='Central Asia']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 121    Armenia
# Name: name, dtype: object

# %%
#6
femdf=carbon_copy[carbon_copy["region"]=='Central America and the Caribbean']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 212    Montserrat
# Name: name, dtype: object

# %%
#7
femdf=carbon_copy[carbon_copy["region"]=='South America']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 211    Falkland Islands (Islas Malvinas)
# Name: name, dtype: object

# %%
#8
femdf=carbon_copy1[carbon_copy1["region"]=='Africa']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 214    Saint Helena, Ascension, and Tristan da Cunha
# Name: name, dtype: object

# %%
#9
femdf=carbon_copy[carbon_copy["region"]=='Antarctica']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 213    Antarctica
# Name: name, dtype: object

# %%
#10
femdf=carbon_copy[carbon_copy["region"]=='Australia and Oceania']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 215    Niue
# Name: name, dtype: object

# %%
#11
femdf=carbon_copy[carbon_copy["region"]=='Middle East']
femdf[femdf.metric_tonnes_of_CO2==femdf.metric_tonnes_of_CO2.min()]["name"]
# Out:
# 141    Gaza Strip
# 142     West Bank
# Name: name, dtype: object

# %% [markdown]
# En el caso 11 obtuvimos dos paises con la menor emision en una misma region.

# %% [markdown]
# ###Parte III

# %%
#Llamamos a la libreria "math"
import math

#Establecemos nuestra variable a incrementar en la tabla 'metric_tonnes_of_CO2_raiz'.
#Luego operamos nuestra variable principal de emisiones con el codigo ".apply(math)".
#Esto debido a que necesitamos aplicarlo a todos los elementos de la columna.
carbon_copy['metric_tonnes_of_CO2_raiz']=carbon_copy['metric_tonnes_of_CO2'].apply(math.sqrt)

#Retornamos a nuestra tabla
print(carbon_copy)
# Out:
#                                               name  metric_tonnes_of_CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information                             region  \
# ...

# %% [markdown]
# ###Parte 4

# %% [markdown]
# Nos solicitan el promedio de los valores de las emisiones de carbono para ello hacemos uso del siguiente código.

# %%
#Guardamos nuestra operacion en la variable del nombre del cual queremos "promedio_CO2".
#Luego llamamos la variable a cambiar con el codigo ".mean()".

promedio_CO2=carbon_copy['metric_tonnes_of_CO2'].mean()

#Imprimos el promedio
print(promedio_CO2)

#El promedio de las emisiones de carbon es:
# Out:
# 171564562.3412037

# %% [markdown]
# ###Parte 5

# %% [markdown]
# Nos solicitan agregar una columna con los valores de la diferencia entre el valor orginal de emision de CO2 con el valor promedio. Para ello hacemos uso del siguiente codigo.

# %%
#Definimos el nombre de la nueva columna a ser agregada a la tabla "carbon_copy".
#Posterior a ello llamamos a la columna con los valores originales de emision de CO2.
#Por ultimo realizamos la operacion con el simbolo "-" agregando despues de este el promedio calculado anteriormente.

carbon_copy['diferencia_metric_promedio']=carbon_copy['metric_tonnes_of_CO2']-promedio_CO2

#Imprimimos la forma de la nueva tabla.
print(carbon_copy)
# Out:
#                                               name  metric_tonnes_of_CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information                             region  \
# ...

# %%
# carbon_copy.to_csv("carbon_copy.csv",index=False)
carbon_copy.to_csv("carbon_copy.csv",index=False)
